# %%
import requests
from bs4 import BeautifulSoup
import json
import logging
from dataclasses import dataclass
from typing import List, Dict, Optional

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s: %(message)s')

@dataclass
class MenuItem:
    name: str
    original_price: float
    predicted_price: float = None

class APIManager:
    def __init__(self):
        # API Keys (consider using environment variables in production)
        self.yelp_api_key = 'kTVg5Li0g4xuwvedMJsfEfJr06A_Mu5lMeLD2ZXFcixT2X2wP_GifvgRFD1sYalB5_WB5FNN-AET2FIQXWwEGN2XFTgoN5bg1d50oDh5T2AQPXyHiL32tdp8YvZTZ3Yx'
        self.weather_api_key = '10b315d964eb2ddfd41ad9df97cc47d5'

    def get_weather_data(self, lat: float, lon: float) -> Optional[Dict]:
        """Fetch weather data from OpenWeatherMap API"""
        try:
            url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={self.weather_api_key}&units=metric"
            response = requests.get(url)
            response.raise_for_status()
            return response.json()
        except requests.RequestException as e:
            logging.error(f"Weather API Error: {e}")
            return None

    def get_restaurant_menu(self) -> List[MenuItem]:
        """Scrape restaurant menu from Yelp"""
        try:
            url = "https://www.yelp.com/menu/village-the-soul-of-india-hicksville"
            headers = {
                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
            }
            response = requests.get(url, headers=headers)
            soup = BeautifulSoup(response.content, 'html.parser')

            menu_items = soup.find_all('p', class_='menu-item-details-description')
            menu_prices = soup.find_all('li', class_='menu-item-price-amount')

            return [
                MenuItem(
                    name=item.text.strip(), 
                    original_price=float(price.text.strip().replace('$', ''))
                ) 
                for item, price in zip(menu_items, menu_prices)
            ]
        except Exception as e:
            logging.error(f"Menu Scraping Error: {e}")
            return []

class PricePredictionEngine:
    @staticmethod
    def predict_prices(
        menu_items: List[MenuItem], 
        weather_data: Dict, 
        is_busy: bool = True
    ) -> List[MenuItem]:
        """
        Predict menu prices based on weather and demand conditions
        
        Conditions for price increase:
        1. Temperature below 45°F (7.2°C)
        2. Snowing or raining
        3. Restaurant is busy
        """
        # Convert temperature to Fahrenheit
        temp_f = (weather_data['main']['temp'] * 9/5) + 32
        
        # Check weather conditions
        weather_description = weather_data['weather'][0]['description'].lower()
        
        # Determine price adjustment conditions
        is_cold = temp_f < 45
        is_bad_weather = any(condition in weather_description for condition in ['snow', 'rain', 'storm'])
        
        # Price prediction logic
        for item in menu_items:
            if is_cold and is_bad_weather and is_busy:
                # 20% price increase when conditions are met
                item.predicted_price = round(item.original_price * 1.2, 2)
            else:
                # Keep original price
                item.predicted_price = item.original_price
        
        return menu_items

class RestaurantAnalyzer:
    def __init__(self):
        self.api_manager = APIManager()
        self.prediction_engine = PricePredictionEngine()

    def analyze_restaurant_menu(self, lat: float = 40.7128, lon: float = -74.0060):
        """
        Comprehensive restaurant menu and price analysis
        
        Args:
            lat (float): Latitude of location
            lon (float): Longitude of location
        """
        try:
            # Fetch weather data
            weather_data = self.api_manager.get_weather_data(lat, lon)
            if not weather_data:
                logging.error("Could not retrieve weather data")
                return

            # Fetch restaurant menu
            menu_items = self.api_manager.get_restaurant_menu()
            if not menu_items:
                logging.error("Could not retrieve menu items")
                return

            # Predict prices
            predicted_menu = self.prediction_engine.predict_prices(
                menu_items, 
                weather_data, 
                is_busy=True
            )

            # Display results
            self.display_results(predicted_menu, weather_data)

        except Exception as e:
            logging.error(f"Analysis Error: {e}")

    def display_results(self, menu_items: List[MenuItem], weather_data: Dict):
        """Display menu analysis results"""
        print("\n--- Village Restaurant Menu Price Analysis ---")
        print(f"Temperature: {weather_data['main']['temp']}°C")
        print(f"Weather: {weather_data['weather'][0]['description']}")
        
        print("\nMenu Items:")
        for item in menu_items:
            price_change = "Increased" if item.predicted_price > item.original_price else "Unchanged"
            print(f"Item: {item.name}")
            print(f"  Original Price: ${item.original_price:.2f}")
            print(f"  Predicted Price: ${item.predicted_price:.2f}")
            print(f"  Price Change: {price_change}\n")

def main():
    # Create and run restaurant analyzer
    analyzer = RestaurantAnalyzer()
    analyzer.analyze_restaurant_menu()

if __name__ == "__main__":
    main()
# Out:
# --- Village Restaurant Menu Price Analysis ---
# Temperature: -2.28°C
# Weather: clear sky
#
# Menu Items:
# Item: Lentil flour donuts.
#   Original Price: $6.00
#   Predicted Price: $6.00
#   Price Change: Unchanged
#
# Item: Lentil flour donuts smothered with sambar.
#   Original Price: $6.99
#   Predicted Price: $6.99
#   Price Change: Unchanged
#
# Item: Lentil flour donuts smothered with Rasam soup.
#   Original Price: $6.99
#   Predicted Price: $6.99
#   Price Change: Unchanged
#
# Item: Rice cake and lentil donut.
#   Original Price: $5.99
#   Predicted Price: $5.99
#   Price Change: Unchanged
#
# Item: Idly and Vada.
#   Original Price: $6.99
#   Predicted Price: $6.99
#   Price Change: Unchanged
#
# Item: Crispy Chenna Dal mixed with spiced and fried.
#   Original Price: $7.45
#   Predicted Price: $7.45
#   Price Change: Unchanged
#
# Item: Lentil donut soaked in sweet yogurt.
#   Original Price: $8.95
#   Predicted Price: $8.95
#   Price Change: Unchanged
#
# Item: Mashed potato spices and fried with chickpeas flour.
#   Original Price: $6.00
#   Predicted Price: $6.00
#   Price Change: Unchanged
#
# Item: Lentil balls spices and cashew fried.
#   Original Price: $6.00
#   Predicted Price: $6.00
#   Price Change: Unchanged
#
# Item: Onions and Chenna Dal spices fried.
#   Original Price: $6.00
#   Predicted Price: $6.00
#   Price Change: Unchanged
#
# Item: Vegetables stuffed platter.
#   Original Price: $7.45
#   Predicted Price: $7.45
#   Price Change: Unchanged
#
# Item: Cottage cheese deep-fried with spices.
#   Original Price: $8.95
#   Predicted Price: $8.95
#   Price Change: Unchanged
#
# Item: Spiced potato with green peas dumplings.
#   Original Price: $6.00
#   Predicted Price: $6.00
#   Price Change: Unchanged
#
# Item: Mashed potato with spiced fried.
#   Original Price: $6.00
#   Predicted Price: $6.00
#   Price Change: Unchanged
#
# Item: South Indian spiced lentil soup.
#   Original Price: $6.00
#   Predicted Price: $6.00
#   Price Change: Unchanged
#
# Item: Lentil based vegetable soup.
#   Original Price: $7.45
#   Predicted Price: $7.45
#   Price Change: Unchanged
#
# Item: Lentil thick soup with pepper and spices.
#   Original Price: $7.45
#   Predicted Price: $7.45
#   Price Change: Unchanged
#
# Item: Mixed vegetables soup.
#   Original Price: $7.45
#   Predicted Price: $7.45
#   Price Change: Unchanged
#
# Item: Simple chopped salad with onions, tomato, and cucumber chips.
#   Original Price: $7.45
#   Predicted Price: $7.45
#   Price Change: Unchanged
#
# Item: Dressing with lettuce, tomato, cucumber, and carrots.
#   Original Price: $7.45
#   Predicted Price: $7.45
#   Price Change: Unchanged
#
# Item: A Savary rice cake from Indian subcontinent.
#   Original Price: $7.45
#   Predicted Price: $7.45
#   Price Change: Unchanged
#
# Item: Rice cakes sauteed with Indian spices and herbs.
#   Original Price: $7.45
#   Predicted Price: $7.45
#   Price Change: Unchanged
#
# Item: Small cocktail idly.
#   Original Price: $7.45
#   Predicted Price: $7.45
#   Price Change: Unchanged
#
# Item: Rice cakes fried with spices and onions.
#   Original Price: $7.45
#   Predicted Price: $7.45
#   Price Change: Unchanged
#
# Item: Rice pancakes spiced with dry Channa Daal powder.
#   Original Price: $9.95
#   Predicted Price: $9.95
#   Price Change: Unchanged
#
# Item: Rice cakes cooked with onion and bell peppering Chinese chilli sauce.
#   Original Price: $7.45
#   Predicted Price: $7.45
#   Price Change: Unchanged
#
# Item: Rice cakes smothered with sambar.
#   Original Price: $9.95
#   Predicted Price: $9.95
#   Price Change: Unchanged
#
# Item: Rice cakes smothered with rasam soup.
#   Original Price: $8.95
#   Predicted Price: $8.95
#   Price Change: Unchanged
#
# Item: Rice cakes soaked in sweet yogurt.
#   Original Price: $9.95
#   Predicted Price: $9.95
#   Price Change: Unchanged
#
# Item: Crispy rice puffs topped with onions, tomato chutney and spices.
#   Original Price: $8.95
#   Predicted Price: $8.95
#   Price Change: Unchanged
#
# Item: Samosas topped with chickpeas, onions, tomato, yogurt, chutney and spices.
#   Original Price: $8.95
#   Predicted Price: $8.95
#   Price Change: Unchanged
#
# Item: Aloo Tikkis topped with chickpeas, onion, tomato, yogurt, chutney, and spices.
#   Original Price: $7.45
#   Predicted Price: $7.45
#   Price Change: Unchanged
#
# Item: Crispy pooris topped chana, onions, tomato, Chutney yogurt, chutney, and spices.
#   Original Price: $8.95
#   Predicted Price: $8.95
#   Price Change: Unchanged
#
# Item: Soft lentil balls dipped in spiced yogurt topped with chutney.
#   Original Price: $8.95
#   Predicted Price: $8.95
#   Price Change: Unchanged
#
# Item: Chickpeas in yogurt, tamarind, cilantro, onion, tomato sauce.
#   Original Price: $9.95
#   Predicted Price: $9.95
#   Price Change: Unchanged
#
# Item: Potato in a yogurt, tamarind, cilantro, onion, tomato sauce.
#   Original Price: $8.95
#   Predicted Price: $8.95
#   Price Change: Unchanged
#
# Item: Potato in a yogurt, tamarind, cilantro, onion, tomato sauce.
#   Original Price: $8.95
#   Predicted Price: $8.95
#   Price Change: Unchanged
#
# Item: A spicy curry of mixed vegetables (Bhaji) cooked in a special blend of spices and served with soft buttered pav.
#   Original Price: $8.95
#   Predicted Price: $8.95
#   Price Change: Unchanged
#
# Item: Vegetables tossed in home style sauce.
#   Original Price: $8.95
#   Predicted Price: $8.95
#   Price Change: Unchanged
#
# Item: Vegetables tossed in home style sauce.
#   Original Price: $8.95
#   Predicted Price: $8.95
#   Price Change: Unchanged
#
# Item: Cottage cheese tossed in our home-made chilli sauce.
#   Original Price: $13.75
#   Predicted Price: $13.75
#   Price Change: Unchanged
#
# Item: Cauliflower tossed in home style sauce.
#   Original Price: $12.95
#   Predicted Price: $12.95
#   Price Change: Unchanged
#
# Item: Mushroom tossed with onion and ball pepper in Chinese sauce.
#   Original Price: $13.75
#   Predicted Price: $13.75
#   Price Change: Unchanged
#
# Item: Sliced potato tossed in dried red chilli and onions.
#   Original Price: $13.75
#   Predicted Price: $13.75
#   Price Change: Unchanged
#
# Item: Onion and cauliflower tossed with home-made sauce and honey.
#   Original Price: $12.95
#   Predicted Price: $12.95
#   Price Change: Unchanged
#
# Item: Cauliflower sauteed with chilli sauces.
#   Original Price: $12.95
#   Predicted Price: $12.95
#   Price Change: Unchanged
#
# Item: Indian-style vegetable hakka noodles have vegetables like onion, cabbage, bell pepper, and carrots.
#   Original Price: $12.95
#   Predicted Price: $12.95
#   Price Change: Unchanged
#
# Item: Cooked rice fried with vegetables and spices.
#   Original Price: $12.95
#   Predicted Price: $12.95
#   Price Change: Unchanged
#
# Item: Topped with noodles, dosa batter, cabbage, capsicum, paneer, peas, lemon juice and some common spices.
#   Original Price: $12.95
#   Predicted Price: $12.95
#   Price Change: Unchanged
#
# Item: Thin rice crepe.
#   Original Price: $13.75
#   Predicted Price: $13.75
#   Price Change: Unchanged
#
# Item: Soft thick rice crepe.
#   Original Price: $12.95
#   Predicted Price: $12.95
#   Price Change: Unchanged
#
# Item: Crepe with mashed potato spices.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Crepe cooked with butter.
#   Original Price: $11.95
#   Predicted Price: $11.95
#   Price Change: Unchanged
#
# Item: Creape cooked with butter and potato.
#   Original Price: $11.95
#   Predicted Price: $11.95
#   Price Change: Unchanged
#
# Item: Clarified butter crepe.
#   Original Price: $12.95
#   Predicted Price: $12.95
#   Price Change: Unchanged
#
# Item: Thin layer crepe.
#   Original Price: $11.95
#   Predicted Price: $11.95
#   Price Change: Unchanged
#
# Item: Spicy red crepe. Spicy.
#   Original Price: $13.75
#   Predicted Price: $13.75
#   Price Change: Unchanged
#
# Item: Spicy red crepe. Spicy.
#   Original Price: $13.75
#   Predicted Price: $13.75
#   Price Change: Unchanged
#
# Item: Crepe with chana dal. Red chilli and spices.
#   Original Price: $12.95
#   Predicted Price: $12.95
#   Price Change: Unchanged
#
# Item: Crepe very spicy with chana dal. Red chilli and spices fried with potato. Spicy.
#   Original Price: $12.95
#   Predicted Price: $12.95
#   Price Change: Unchanged
#
# Item: Crepe cooked with onion and chilli.
#   Original Price: $12.95
#   Predicted Price: $12.95
#   Price Change: Unchanged
#
# Item: Crepe topped with chopped onions and green chilis.
#   Original Price: $12.95
#   Predicted Price: $12.95
#   Price Change: Unchanged
#
# Item: Crepe cooked with mushroom and spiced potatoes.
#   Original Price: $12.95
#   Predicted Price: $12.95
#   Price Change: Unchanged
#
# Item: Paneer, potato, onion, tomato, chillis.
#   Original Price: $12.95
#   Predicted Price: $12.95
#   Price Change: Unchanged
#
# Item: Crepe cooked with Cottage cheese and potato.
#   Original Price: $12.95
#   Predicted Price: $12.95
#   Price Change: Unchanged
#
# Item: Crepe cooked with Cottage cheese, onions, bell pepper.
#   Original Price: $24.95
#   Predicted Price: $24.95
#   Price Change: Unchanged
#
# Item: Crepe cooked with spinach and potato spices.
#   Original Price: $13.75
#   Predicted Price: $13.75
#   Price Change: Unchanged
#
# Item: Crepe cooked with cheddar cheese and spices.
#   Original Price: $13.75
#   Predicted Price: $13.75
#   Price Change: Unchanged
#
# Item: Crepe cooked with cheddar cheese.
#   Original Price: $13.75
#   Predicted Price: $13.75
#   Price Change: Unchanged
#
# Item: Crepe cooked with cheddar cheese.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Crepe cooked with cabbage, onions, ball pepper, and potato.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Crepe rolled and filled with potato and spices.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Crepe rolled and filled with potato and spices.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Crepe made spicy filled with Cottage cheese and potato.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Lentil and rice flour pancake.
#   Original Price: $13.75
#   Predicted Price: $13.75
#   Price Change: Unchanged
#
# Item: Thick rice pancakes topped with vegetables looks like pizza no cheese.
#   Original Price: $13.75
#   Predicted Price: $13.75
#   Price Change: Unchanged
#
# Item: Topped with onion and green chilli.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Topped with onion and sliced mushroom.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Topped with chilli, tomato and garlic.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Topped with Dosa Podi and gunpowder.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Topped with onion, tomato, peas, carrots, and cheese.
#   Original Price: $15.00
#   Predicted Price: $15.00
#   Price Change: Unchanged
#
# Item: Topped with sliced paneer.
#   Original Price: $11.95
#   Predicted Price: $11.95
#   Price Change: Unchanged
#
# Item: Semolina crepe only.
#   Original Price: $12.95
#   Predicted Price: $12.95
#   Price Change: Unchanged
#
# Item: Semolina crepe with mashed spiced potato.
#   Original Price: $13.75
#   Predicted Price: $13.75
#   Price Change: Unchanged
#
# Item: Semolina crepe made spicy with house spices.
#   Original Price: $13.75
#   Predicted Price: $13.75
#   Price Change: Unchanged
#
# Item: Semolina crepe made with onion chilli and house spices.
#   Original Price: $13.75
#   Predicted Price: $13.75
#   Price Change: Unchanged
#
# Item: Rava Dosa filled with cheese, onions and seasoned potato filling.
#   Original Price: $13.75
#   Predicted Price: $13.75
#   Price Change: Unchanged
#
# Item: Rava Dosa filled with coconut.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Mix veg cooked with paneer, cream, and cheese.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Dosa cooked and rolled with vegetables.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Rava or regular. Dosa cooked with garlic, chilli, onion and cheese.
#   Original Price: $18.00
#   Predicted Price: $18.00
#   Price Change: Unchanged
#
# Item: Potato and creamed spinach, green peas, cauliflower mildly spiced tomato sauce.
#   Original Price: $13.75
#   Predicted Price: $13.75
#   Price Change: Unchanged
#
# Item: Potato and creamed spinach, green peas, cauliflower mildly spiced tomato sauce.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Potato and creamed spinach, green peas, cauliflower mildly spiced tomato sauce.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Fresh cauliflower cooked in onion base sauce.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Fresh cauliflower cooked in onion base sauce.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Chickpea, onion and masala spices.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Spinach and chickpeas cooked with spices.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Yellow lentils cooked and spices with your choice of spinach or no spinach.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Yellow lentils cooked and spices.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Green peas and homemade cheese cooked with spices.
#   Original Price: $15.00
#   Predicted Price: $15.00
#   Price Change: Unchanged
#
# Item: Spinach and homemade cheese cooked with spices.
#   Original Price: $18.00
#   Predicted Price: $18.00
#   Price Change: Unchanged
#
# Item: Cooked spinach studded with cubes of fried paneer cheese.
#   Original Price: $18.00
#   Predicted Price: $18.00
#   Price Change: Unchanged
#
# Item: Cubes of paneer and veggies marinated with yogurt and spices.
#   Original Price: $18.00
#   Predicted Price: $18.00
#   Price Change: Unchanged
#
# Item: Fresh cheese made by curdling milk with lemon.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Fresh methi leaves with green peas and creamy in a sweet, rich, and creamy curry.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Hot, spicy, flavorful button mushrooms and bell peppers.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Paneer dumplings served with rich, creamy, and delicious gravy.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Scrambled paneer or Cottage cheese with a spiced mixture made of onions, ginger garlic paste.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Made with okra, whole and ground spices, onions and tomatoes.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Roasted eggplant (Brinjal) stars in this strong-flavoured curry.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Roasted eggplant mash cooked with spices.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Rich luxurious curry dish made with mixed vegetables.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Loaded with potatoes, tomatoes, carrots, peas, and green beans. Vegan.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Made with diced potatoes and eggplant that have been simmered in a spiced onion tomato.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Coconut-based spicy curry with vegetables.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Garlic. Gravy made with a tamarind based broth and loaded with lots of garlic.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Eggplant. Gravy in which brinjal are stuffed with flavorful fresh ground masalas and sauteed in oil.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Okra. Tender okra. Lady's finger is simmered in tangy tamarind gravy.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Drumstick. A spicy and tangy tamarind based curry made with drumsticks.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Idly, vada, dosa, uthappam, sambar, chutney, badam halwa.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Sambar, rasam, kulambu, kootu avial, poriyal, pickle, yogurt, pappadam, rice, semiya payasam.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Chole, daal, any paneer - rice, roti, pickle, raita, kheer, pappad.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Large puffed bread with spicy chickpeas.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Large puffed bread with spicy chickpeas.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Spiced aloo or sabji or bhaji with hints of coriander, ginger and other Indian spices.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Semolina with onion, cashews, chilli with Indian spices.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Rice, lentil, spices, nuts, and butter. Served with coconut chutney and sambar.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Mixed vegetables cooked with coconut milk, yogurt and spices.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Indian layerd bread chopped and cooked with Chineese sauce, ginger, and garlic.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Fried unleavened bread.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Puffed up fried bread.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Onion paratha.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Onion.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Goodness of rice and vegetables that comes in layers.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Basmati rice, vegetables, and spices.
#   Original Price: $21.95
#   Predicted Price: $21.95
#   Price Change: Unchanged
#
# Item: Riced cooked with lemon juice and spices.
#   Original Price: $21.95
#   Predicted Price: $21.95
#   Price Change: Unchanged
#
# Item: Rice cooked with tamarind and spices.
#   Original Price: $21.95
#   Predicted Price: $21.95
#   Price Change: Unchanged
#
# Item: Rice, lentil and eggplant cooked with spices.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Rice cooked with tomato and spices.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Rice cooked with ground coconut and nuts.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Rice smothered with yogurt.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Choice of soda.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Choice of flavor.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Hot drink.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Hot drink.
#   Original Price: $14.95
#   Predicted Price: $14.95
#   Price Change: Unchanged
#
# Item: Hot drink.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Choice of flavor.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Made with Club soda.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
#
# Item: Made with Thums-up.
#   Original Price: $16.00
#   Predicted Price: $16.00
#   Price Change: Unchanged
